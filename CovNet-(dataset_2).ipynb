# %% [markdown]
# <a href="https://colab.research.google.com/github/Shihab7u/Brain-Tumor-Detection-and-Classification/blob/main/CovNet-(dataset_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.0

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1SF24UZbOh9oCOnhc_NAo9aQtVAA-vtwl/view?usp=share_link
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SF24UZbOh9oCOnhc_NAo9aQtVAA-vtwl
# To: /content/Brain_Image_Data.zip
# 100% 91.0M/91.0M [00:00<00:00, 91.6MB/s]

# %%
# !unzip "/content/Brain_Image_Data.zip" > /dev/null

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.layers import Input

# %%
path = os.listdir('/content/Training/')
classes = {'glioma_tumor':0, 'meningioma_tumor':1, 'no_tumor':2, 'pituitary_tumor':3}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth1 = '/content/Training/'+cls
    for j in os.listdir(pth1):
        img = cv2.imread(pth1+'/'+j, 1) #0 for input shape (256,256,3) have to repalce 0 with 1
        img = cv2.resize(img, (224,224)) #256,256
        X.append(img)
        Y.append(classes[cls])

for cls in classes:
    pth2 = '/content/Testing/'+cls
    for j in os.listdir(pth2):
        img = cv2.imread(pth2+'/'+j, 1) #0 for input shape (256,256,3) have to repalce 0 with 1
        img = cv2.resize(img, (224,224)) #256,256
        X.append(img)
        Y.append(classes[cls])

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet import preprocess_input

# %%
def preprocessingImages1(path):
  """
  input : path
  output : preprocessed image
  """
  image_data = ImageDataGenerator(zoom_range=0.2, shear_range=0.2, preprocessing_function = preprocess_input, horizontal_flip = True) # data agumentation, zoom range = 0.2, shear_range = 0.2
  image = image_data.flow_from_directory(directory=path, target_size=(224,224), batch_size=32, class_mode = 'categorical') #batch size

  return image

# %%
def preprocessingImages2(path):
  """
  input : path
  output : preprocessed image
  """
  image_data = ImageDataGenerator(preprocessing_function = preprocess_input)
  image = image_data.flow_from_directory(directory=path, target_size=(224,224), batch_size=32, class_mode = 'categorical')

  return image

# %%
path = "/content/Training/"
train_data = preprocessingImages1(path)
# Out:
# Found 2870 images belonging to 4 classes.

# %%
path = "/content/Testing/"
test_data =  preprocessingImages2(path)
# Out:
# Found 394 images belonging to 4 classes.

# %%
X = np.array(X)
Y = np.array(Y)

# %%
plt.imshow(X[0], cmap='gray')

# %%
X[0].shape
# Out:
# (224, 224, 3)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, random_state=10,test_size=.20) #random_state=10

# %%
xtrain.shape, xtest.shape
# Out:
# ((2611, 224, 224, 3), (653, 224, 224, 3))

# %%
#Model building starts
from tensorflow.keras.models import Model, Sequential
import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input,Bidirectional,LSTM,Lambda, GRU
from tensorflow.keras.layers import Permute,GlobalMaxPool1D,Concatenate, Dense, BatchNormalization, Dropout, GlobalAveragePooling1D, GlobalAveragePooling2D,Add
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import Dense, Activation, Flatten,MaxPooling1D,Conv1D, Conv2D,MaxPool2D,MaxPooling2D

# %%
model = Sequential()


model.add(Conv2D(32, 5, activation='relu',input_shape = (224,224,3))) #3 Conv1D
model.add(MaxPooling2D(pool_size=4)) #2
model.add(BatchNormalization())
model.add(Dropout(0.1))


model.add(Conv2D(64, 5, activation='relu'))
model.add(Conv2D(64, 5, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Conv2D(128, 5, activation='relu')) #2
model.add(MaxPooling2D(pool_size=2))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Conv2D(256, 5, activation='relu')) #2
model.add(MaxPooling2D(pool_size=2))
model.add(BatchNormalization())
model.add(Dropout(0.1))




model.add(Flatten())
model.add(Dense(256, activation='relu')) #128
model.add(BatchNormalization())
model.add(Dropout(0.1)) #0.3
model.add(Dense(128, activation='softmax')) #128

# %%
# plot model architecture
from keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='CNN Architecture.png')

# %%
 model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 220, 220, 32)      2432
#
#  max_pooling2d_39 (MaxPoolin  (None, 55, 55, 32)       0
#  g2D)
#
#  batch_normalization_49 (Bat  (None, 55, 55, 32)       128
#  chNormalization)
#
#  dropout_41 (Dropout)        (None, 55, 55, 32)        0
#
#  conv2d_46 (Conv2D)          (None, 51, 51, 64)        51264
#
#  conv2d_47 (Conv2D)          (None, 47, 47, 64)        102464
#
#  max_pooling2d_40 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  batch_normalization_50 (Bat  (None, 23, 23, 64)       256
#  chNormalization)
#
#  dropout_42 (Dropout)        (None, 23, 23, 64)        0
#
#  conv2d_48 (Conv2D)          (None, 19, 19, 128)       204928
#
#  max_pooling2d_41 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  batch_normalization_51 (Bat  (None, 9, 9, 128)        512
#  chNormalization)
#
#  dropout_43 (Dropout)        (None, 9, 9, 128)         0
#
#  conv2d_49 (Conv2D)          (None, 5, 5, 256)         819456
#
#  max_pooling2d_42 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  batch_normalization_52 (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  dropout_44 (Dropout)        (None, 2, 2, 256)         0
#
#  flatten_8 (Flatten)         (None, 1024)              0
#
#  dense_20 (Dense)            (None, 256)               262400
#
#  batch_normalization_53 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_45 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 128)               32896
#
# =================================================================
# Total params: 1,478,784
# Trainable params: 1,477,312
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',
            loss='sparse_categorical_crossentropy',
             metrics=["accuracy"])

# %%
r=model.fit(xtrain,
          ytrain,
          epochs=50,
          batch_size=32,
          verbose=1,
          validation_data=(xtest,ytest),
          shuffle=False
          )
# Out:
# Epoch 1/50
# 82/82 [==============================] - 6s 59ms/step - loss: 2.0025 - accuracy: 0.6488 - val_loss: 19.2324 - val_accuracy: 0.1455
# Epoch 2/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.8994 - accuracy: 0.7878 - val_loss: 5.4570 - val_accuracy: 0.2236
# Epoch 3/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.4952 - accuracy: 0.8449 - val_loss: 4.7038 - val_accuracy: 0.3338
# Epoch 4/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.3130 - accuracy: 0.8935 - val_loss: 0.8136 - val_accuracy: 0.7274
# Epoch 5/50
# 82/82 [==============================] - 4s 49ms/step - loss: 0.1706 - accuracy: 0.9441 - val_loss: 0.4675 - val_accuracy: 0.8377
# Epoch 6/50
# 82/82 [==============================] - 4s 49ms/step - loss: 0.1357 - accuracy: 0.9556 - val_loss: 0.3901 - val_accuracy: 0.8959
# Epoch 7/50
# 82/82 [==============================] - 4s 49ms/step - loss: 0.1139 - accuracy: 0.9625 - val_loss: 1.1457 - val_accuracy: 0.6662
# Epoch 8/50
# 82/82 [==============================] - 4s 49ms/step - loss: 0.1212 - accuracy: 0.9640 - val_loss: 1.8133 - val_accuracy: 0.5360
# Epoch 9/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0768 - accuracy: 0.9732 - val_loss: 2.8405 - val_accuracy: 0.4395
# Epoch 10/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0516 - accuracy: 0.9824 - val_loss: 0.2868 - val_accuracy: 0.9296
# Epoch 11/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0343 - accuracy: 0.9885 - val_loss: 0.3598 - val_accuracy: 0.9158
# Epoch 12/50
# 82/82 [==============================] - 4s 50ms/step - loss: 0.0209 - accuracy: 0.9939 - val_loss: 0.5211 - val_accuracy: 0.8851
# Epoch 13/50
# 82/82 [==============================] - 4s 50ms/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.5072 - val_accuracy: 0.8683
# Epoch 14/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.2829 - val_accuracy: 0.9387
# Epoch 15/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.3101 - val_accuracy: 0.9479
# Epoch 16/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.4268 - val_accuracy: 0.8959
# Epoch 17/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.2407 - val_accuracy: 0.9525
# Epoch 18/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2822 - val_accuracy: 0.9433
# Epoch 19/50
# 82/82 [==============================] - 4s 48ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9495
# Epoch 20/50
# 82/82 [==============================] - 4s 48ms/step - loss: 9.3608e-04 - accuracy: 1.0000 - val_loss: 0.2514 - val_accuracy: 0.9525
# Epoch 21/50
# 82/82 [==============================] - 4s 48ms/step - loss: 6.9592e-04 - accuracy: 1.0000 - val_loss: 0.2533 - val_accuracy: 0.9541
# Epoch 22/50
# 82/82 [==============================] - 4s 48ms/step - loss: 7.5240e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9556
# Epoch 23/50
# 82/82 [==============================] - 4s 48ms/step - loss: 9.9987e-04 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9571
# Epoch 24/50
# 82/82 [==============================] - 4s 48ms/step - loss: 5.0996e-04 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9556
# Epoch 25/50
# 82/82 [==============================] - 4s 48ms/step - loss: 4.5536e-04 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.9525
# Epoch 26/50
# 82/82 [==============================] - 4s 48ms/step - loss: 5.3405e-04 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9571
# Epoch 27/50
# 82/82 [==============================] - 4s 48ms/step - loss: 3.9083e-04 - accuracy: 1.0000 - val_loss: 0.2544 - val_accuracy: 0.9571
# Epoch 28/50
# 82/82 [==============================] - 4s 48ms/step - loss: 3.9656e-04 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9571
# Epoch 29/50
# 82/82 [==============================] - 4s 49ms/step - loss: 3.2728e-04 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9556
# Epoch 30/50
# 82/82 [==============================] - 4s 48ms/step - loss: 2.5682e-04 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.9571
# Epoch 31/50
# 82/82 [==============================] - 4s 48ms/step - loss: 2.5611e-04 - accuracy: 1.0000 - val_loss: 0.2683 - val_accuracy: 0.9571
# Epoch 32/50
# 82/82 [==============================] - 4s 48ms/step - loss: 2.2791e-04 - accuracy: 1.0000 - val_loss: 0.2666 - val_accuracy: 0.9541
# Epoch 33/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.9826e-04 - accuracy: 1.0000 - val_loss: 0.2713 - val_accuracy: 0.9571
# Epoch 34/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.8597e-04 - accuracy: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9587
# Epoch 35/50
# 82/82 [==============================] - 4s 48ms/step - loss: 2.3864e-04 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9571
# Epoch 36/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.7208e-04 - accuracy: 1.0000 - val_loss: 0.2685 - val_accuracy: 0.9587
# Epoch 37/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.6418e-04 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.9587
# Epoch 38/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.7921e-04 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.9571
# Epoch 39/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.4840e-04 - accuracy: 1.0000 - val_loss: 0.2746 - val_accuracy: 0.9571
# Epoch 40/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.3188e-04 - accuracy: 1.0000 - val_loss: 0.2891 - val_accuracy: 0.9571
# Epoch 41/50
# 82/82 [==============================] - 4s 49ms/step - loss: 4.8735e-04 - accuracy: 1.0000 - val_loss: 0.3522 - val_accuracy: 0.9342
# Epoch 42/50
# 82/82 [==============================] - 4s 48ms/step - loss: 2.7020e-04 - accuracy: 1.0000 - val_loss: 0.2984 - val_accuracy: 0.9464
# Epoch 43/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.5315e-04 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.9525
# Epoch 44/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.4460e-04 - accuracy: 1.0000 - val_loss: 0.2873 - val_accuracy: 0.9571
# Epoch 45/50
# 82/82 [==============================] - 4s 48ms/step - loss: 1.2616e-04 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9525
# Epoch 46/50
# 82/82 [==============================] - 4s 49ms/step - loss: 1.0992e-04 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.9571
# Epoch 47/50
# 82/82 [==============================] - 4s 49ms/step - loss: 9.5143e-05 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9556
# Epoch 48/50
# 82/82 [==============================] - 4s 48ms/step - loss: 9.5079e-05 - accuracy: 1.0000 - val_loss: 0.2959 - val_accuracy: 0.9571
# Epoch 49/50
# 82/82 [==============================] - 4s 49ms/step - loss: 9.8261e-05 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9602
# Epoch 50/50
# 82/82 [==============================] - 4s 49ms/step - loss: 7.1639e-05 - accuracy: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.9587

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
t = f.suptitle('CNN Performance for imagedata', fontsize=12 )
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(0,50))
ax1.plot(epoch_list, r.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, r.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 50, 4))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, r.history['loss'], label='Train Loss')
ax2.plot(epoch_list, r.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 50, 4))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")


plt.savefig('CNN Performance imagedata.png')

# %%
pred=model.predict(xtest)
Y_pred = np.argmax(pred, 1)
# Out:
# 21/21 [==============================] - 0s 16ms/step

# %%
Y_pred.shape
# Out:
# (653,)

# %%
ytest.shape
# Out:
# (653,)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
print(confusion_matrix(ytest, Y_pred))
# Out:
# Confusion Matrix
# [[172   7   4   1]
#  [  7 195   0   3]
#  [  3   1  90   1]
#  [  0   0   0 169]]

# %%
import seaborn as sns
cm=confusion_matrix(ytest, Y_pred)
plt.figure(dpi=300),sns.heatmap(cm, square=True, annot=True, fmt=".1f", cbar=False, cmap=plt.cm.Blues)
plt.xlabel('Predicted Values')
plt.ylabel('True Values');

# %%
print('Classification Report')
target_names = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
print(classification_report(ytest, Y_pred, target_names=target_names))
# Out:
# Classification Report
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.95      0.93      0.94       184
# meningioma_tumor       0.96      0.95      0.96       205
#         no_tumor       0.96      0.95      0.95        95
#  pituitary_tumor       0.97      1.00      0.99       169
#
#         accuracy                           0.96       653
#        macro avg       0.96      0.96      0.96       653
#     weighted avg       0.96      0.96      0.96       653

# %%
print(ytrain)
# Out:
# [3 1 0 ... 0 3 1]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


ax= plt.subplot()
plt.figure(dpi=300),sns.heatmap(cm, annot=True, ax = ax, fmt=".1f"); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['glioma', 'meningioma', 'no_tumor', 'pituitary']); ax.yaxis.set_ticklabels(['glioma', 'meningioma', 'no_tumor', 'pituitary'])
# Out:
# [Text(0, 0.5, 'glioma'),
#  Text(0, 1.5, 'meningioma'),
#  Text(0, 2.5, 'no_tumor'),
#  Text(0, 3.5, 'pituitary')]

# %%
from sklearn.metrics import accuracy_score
results = confusion_matrix(ytest,Y_pred)
print('Confusion Matrix :')
print(results)
print('Accuracy Score :',accuracy_score(ytest,Y_pred))
print('Report : ')
print(classification_report(ytest,Y_pred))

plt.figure(dpi=300),sns.heatmap(results/np.sum(results), annot=True,
            fmt='.2%', cmap='Blues')
# Out:
# Confusion Matrix :
# [[172   7   4   1]
#  [  7 195   0   3]
#  [  3   1  90   1]
#  [  0   0   0 169]]
# Accuracy Score : 0.9586523736600306
# Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       184
#            1       0.96      0.95      0.96       205
#            2       0.96      0.95      0.95        95
#            3       0.97      1.00      0.99       169
#
#     accuracy                           0.96       653
#    macro avg       0.96      0.96      0.96       653
# weighted avg       0.96      0.96      0.96       653
# (<Figure size 1800x1200 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f8cec217e80>)

# %%
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(ytest, Y_pred, pos_label=2)
metrics.auc(fpr, tpr)
# Out:
# 0.6694963214487832

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(fpr, tpr)
ax.plot(np.linspace(0, 1, 100),
         np.linspace(0, 1, 100),
         label='baseline',
         linestyle='--')
plt.title('Receiver Operating Characteristic Curve', fontsize=14)
plt.ylabel('Total Positive Rate', fontsize=12)
plt.xlabel('False Positive Rate', fontsize=12)
plt.legend(fontsize=12);
